# %%
# import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy

# %%
# Create longitudes and latitudes
lat= np.random.uniform(low=-90, high=90, size=2000)
lon= np.random.uniform(low=-180, high=180, size=2000)
lat_lon= zip(lat, lon)
lat_lon

# %%
# Create longitude and latitude 
coordinates = list(lat_lon)

# %%
# Create list for cities
cities= []
for coordinate in coordinates:
    city= citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 754

# %%
# import requests library and API key
import requests

from config import weather_api_key

# Url for weather map api call
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descrip = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Conditions": city_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | calvia
# Processing Record 3 of Set 1 | son la
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | lebu
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 1 | kodiak
# Processing Record 10 of Set 1 | itabaiana
# Processing Record 11 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | vanimo
# Processing Record 14 of Set 1 | pevek
# Processing Record 15 of Set 1 | cherskiy
# Processing Record 16 of Set 1 | nsunga
# Processing Record 17 of Set 1 | vardo
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | tigil
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | nenton
# Processing Record 22 of Set 1 | grindavik
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | tateyama
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | kapaa
# Processing Record 27 of Set 1 | ulundi
# Processing Record 28 of Set 1 | aketi
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | niquelandia
# Processing Record 31 of Set 1 | haverfordwest
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | campbell river
# Processing Record 35 of Set 1 | ponta do sol
# Processing Record 36 of Set 1 | dikson
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | valenca do piaui
# Processing Record 40 of Set 1 | ternovskaya
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | kaitangata
# Processing Record 43 of Set 1 | mahebourg
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | norden
# Processing Record 47 of Set 1 | hami
# Processing Record 48 of Set 1 | walvis bay
# Processing Record 49 of Set 1 | muscat
# Processing Record 50 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 2 | mar del plata
# Processing Record 2 of Set 2 | chimbote
# Processing Record 3 of Set 2 | san vicente
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | tuatapere
# Processing Record 7 of Set 2 | juneau
# Processing Record 8 of Set 2 | ilhabela
# Processing Record 9 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | talnakh
# Processing Record 13 of Set 2 | jamestown
# Processing Record 14 of Set 2 | avarua
# Processing Record 15 of Set 2 | souillac
# Processing Record 16 of Set 2 | saldanha
# Processing Record 17 of Set 2 | saint george
# Processing Record 18 of Set 2 | minden
# Processing Record 19 of Set 2 | storforshei
# Processing Record 20 of Set 2 | san cristobal
# Processing Record 21 of Set 2 | khani
# Processing Record 22 of Set 2 | antipolo
# Processing Record 23 of Set 2 | narsaq
# Processing Record 24 of Set 2 | comodoro rivadavia
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | lompoc
# Processing Record 27 of Set 2 | marystown
# Processing Record 28 of Set 2 | thompson
# Processing Record 29 of Set 2 | bluff
# Processing Record 30 of Set 2 | umm lajj
# Processing Record 31 of Set 2 | lure
# Processing Record 32 of Set 2 | flinders
# Processing Record 33 of Set 2 | bang saphan
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 2 | sao joao do piaui
# Processing Record 36 of Set 2 | sola
# Processing Record 37 of Set 2 | kapuskasing
# Processing Record 38 of Set 2 | hilo
# Processing Record 39 of Set 2 | nova odesa
# Processing Record 40 of Set 2 | carmen
# Processing Record 41 of Set 2 | waingapu
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | ust-tsilma
# Processing Record 44 of Set 2 | hambantota
# Processing Record 45 of Set 2 | port macquarie
# Processing Record 46 of Set 2 | gualaquiza
# Processing Record 47 of Set 2 | bosaso
# Processing Record 48 of Set 2 | lar gerd
# City not found. Skipping...
# Processing Record 49 of Set 2 | port alfred
# Processing Record 50 of Set 2 | turukhansk
# Processing Record 1 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | mersing
# Processing Record 4 of Set 3 | popondetta
# Processing Record 5 of Set 3 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 3 | kununurra
# Processing Record 7 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 3 | silvan
# Processing Record 9 of Set 3 | tarko-sale
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | tuktoyaktuk
# Processing Record 13 of Set 3 | timbiqui
# Processing Record 14 of Set 3 | talakan
# Processing Record 15 of Set 3 | hamilton
# Processing Record 16 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 3 | coquimbo
# Processing Record 18 of Set 3 | jian
# Processing Record 19 of Set 3 | georgetown
# Processing Record 20 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 3 | mount isa
# Processing Record 22 of Set 3 | santa fe
# Processing Record 23 of Set 3 | chipinge
# Processing Record 24 of Set 3 | igarka
# Processing Record 25 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 26 of Set 3 | roald
# Processing Record 27 of Set 3 | davidson
# Processing Record 28 of Set 3 | shar
# Processing Record 29 of Set 3 | nanortalik
# Processing Record 30 of Set 3 | namibe
# Processing Record 31 of Set 3 | trincomalee
# Processing Record 32 of Set 3 | laguna
# Processing Record 33 of Set 3 | olinda
# Processing Record 34 of Set 3 | korla
# Processing Record 35 of Set 3 | pringsewu
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | meulaboh
# Processing Record 38 of Set 3 | cockburn town
# Processing Record 39 of Set 3 | ixtapa
# Processing Record 40 of Set 3 | butaritari
# Processing Record 41 of Set 3 | vila velha
# Processing Record 42 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 43 of Set 3 | hithadhoo
# Processing Record 44 of Set 3 | qiongshan
# Processing Record 45 of Set 3 | westport
# Processing Record 46 of Set 3 | hammerfest
# Processing Record 47 of Set 3 | port antonio
# Processing Record 48 of Set 3 | lichinga
# Processing Record 49 of Set 3 | saint-augustin
# Processing Record 50 of Set 3 | finschhafen
# Processing Record 1 of Set 4 | mangochi
# Processing Record 2 of Set 4 | nome
# Processing Record 3 of Set 4 | college
# Processing Record 4 of Set 4 | cairns
# Processing Record 5 of Set 4 | port-gentil
# Processing Record 6 of Set 4 | ketchikan
# Processing Record 7 of Set 4 | kuching
# Processing Record 8 of Set 4 | cap malheureux
# Processing Record 9 of Set 4 | tessalit
# Processing Record 10 of Set 4 | olga
# Processing Record 11 of Set 4 | cape town
# Processing Record 12 of Set 4 | torbay
# Processing Record 13 of Set 4 | taganak
# Processing Record 14 of Set 4 | pacific grove
# Processing Record 15 of Set 4 | marmande
# Processing Record 16 of Set 4 | faanui
# Processing Record 17 of Set 4 | upernavik
# Processing Record 18 of Set 4 | calabozo
# Processing Record 19 of Set 4 | chokurdakh
# Processing Record 20 of Set 4 | nioro
# Processing Record 21 of Set 4 | villa carlos paz
# Processing Record 22 of Set 4 | berdigestyakh
# Processing Record 23 of Set 4 | narasaraopet
# Processing Record 24 of Set 4 | iqaluit
# Processing Record 25 of Set 4 | biak
# Processing Record 26 of Set 4 | vila
# Processing Record 27 of Set 4 | prince rupert
# Processing Record 28 of Set 4 | kalmunai
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | srednekolymsk
# Processing Record 31 of Set 4 | kumluca
# Processing Record 32 of Set 4 | lorengau
# Processing Record 33 of Set 4 | luderitz
# Processing Record 34 of Set 4 | kollegal
# Processing Record 35 of Set 4 | vestbygda
# City not found. Skipping...
# Processing Record 36 of Set 4 | clyde river
# Processing Record 37 of Set 4 | bredasdorp
# Processing Record 38 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 4 | salalah
# Processing Record 40 of Set 4 | jieshi
# Processing Record 41 of Set 4 | conceicao do araguaia
# Processing Record 42 of Set 4 | port blair
# Processing Record 43 of Set 4 | sao desiderio
# Processing Record 44 of Set 4 | lagoa
# Processing Record 45 of Set 4 | tiarei
# Processing Record 46 of Set 4 | bauchi
# Processing Record 47 of Set 4 | conde
# Processing Record 48 of Set 4 | ayagoz
# Processing Record 49 of Set 4 | grong
# Processing Record 50 of Set 4 | talaya
# Processing Record 1 of Set 5 | shelburne
# Processing Record 2 of Set 5 | porto velho
# Processing Record 3 of Set 5 | severo-kurilsk
# Processing Record 4 of Set 5 | gwembe
# Processing Record 5 of Set 5 | thermon
# City not found. Skipping...
# Processing Record 6 of Set 5 | san quintin
# Processing Record 7 of Set 5 | port elizabeth
# Processing Record 8 of Set 5 | navrongo
# Processing Record 9 of Set 5 | tilichiki
# Processing Record 10 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 5 | porto novo
# Processing Record 12 of Set 5 | kavieng
# Processing Record 13 of Set 5 | bambanglipuro
# Processing Record 14 of Set 5 | luwuk
# Processing Record 15 of Set 5 | umm kaddadah
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | quesnel
# Processing Record 18 of Set 5 | hoganas
# Processing Record 19 of Set 5 | tulsipur
# Processing Record 20 of Set 5 | bathsheba
# Processing Record 21 of Set 5 | asau
# Processing Record 22 of Set 5 | nileshwar
# Processing Record 23 of Set 5 | jumla
# Processing Record 24 of Set 5 | mount pleasant
# Processing Record 25 of Set 5 | bonavista
# Processing Record 26 of Set 5 | muros
# Processing Record 27 of Set 5 | naze
# Processing Record 28 of Set 5 | palmer
# Processing Record 29 of Set 5 | ostrovnoy
# Processing Record 30 of Set 5 | leshan
# Processing Record 31 of Set 5 | sinnamary
# Processing Record 32 of Set 5 | nhulunbuy
# Processing Record 33 of Set 5 | odesskoye
# Processing Record 34 of Set 5 | aksarka
# Processing Record 35 of Set 5 | verkhnyaya inta
# Processing Record 36 of Set 5 | matagami
# Processing Record 37 of Set 5 | te anau
# Processing Record 38 of Set 5 | hurghada
# Processing Record 39 of Set 5 | cuamba
# Processing Record 40 of Set 5 | sao jose da coroa grande
# Processing Record 41 of Set 5 | krasnovka
# Processing Record 42 of Set 5 | estelle
# Processing Record 43 of Set 5 | kiruna
# Processing Record 44 of Set 5 | aguimes
# Processing Record 45 of Set 5 | vrangel
# Processing Record 46 of Set 5 | sawtell
# Processing Record 47 of Set 5 | norman wells
# Processing Record 48 of Set 5 | sitka
# Processing Record 49 of Set 5 | coahuayana
# Processing Record 50 of Set 5 | kieta
# Processing Record 1 of Set 6 | monte alegre
# Processing Record 2 of Set 6 | esperance
# Processing Record 3 of Set 6 | tupa
# Processing Record 4 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 6 | taltal
# Processing Record 6 of Set 6 | dire
# Processing Record 7 of Set 6 | broken hill
# Processing Record 8 of Set 6 | vostok
# Processing Record 9 of Set 6 | chuy
# Processing Record 10 of Set 6 | fortuna
# Processing Record 11 of Set 6 | dryden
# Processing Record 12 of Set 6 | hachinohe
# Processing Record 13 of Set 6 | constitucion
# Processing Record 14 of Set 6 | shingu
# Processing Record 15 of Set 6 | kelvington
# Processing Record 16 of Set 6 | san patricio
# Processing Record 17 of Set 6 | tevriz
# Processing Record 18 of Set 6 | east london
# Processing Record 19 of Set 6 | victoria
# Processing Record 20 of Set 6 | pangody
# Processing Record 21 of Set 6 | davila
# Processing Record 22 of Set 6 | freeport
# Processing Record 23 of Set 6 | qaqortoq
# Processing Record 24 of Set 6 | nicolas bravo
# Processing Record 25 of Set 6 | bambous virieux
# Processing Record 26 of Set 6 | hay river
# Processing Record 27 of Set 6 | pangnirtung
# Processing Record 28 of Set 6 | rawson
# Processing Record 29 of Set 6 | le vauclin
# Processing Record 30 of Set 6 | lata
# Processing Record 31 of Set 6 | ghanzi
# Processing Record 32 of Set 6 | luhyny
# Processing Record 33 of Set 6 | ponta pora
# Processing Record 34 of Set 6 | imbituba
# Processing Record 35 of Set 6 | gayeri
# Processing Record 36 of Set 6 | tommot
# Processing Record 37 of Set 6 | sungaipenuh
# Processing Record 38 of Set 6 | vestmannaeyjar
# Processing Record 39 of Set 6 | saint-philippe
# Processing Record 40 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 41 of Set 6 | ullapool
# Processing Record 42 of Set 6 | boulder
# Processing Record 43 of Set 6 | san esteban
# Processing Record 44 of Set 6 | padang
# Processing Record 45 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 46 of Set 6 | christchurch
# Processing Record 47 of Set 6 | one hundred mile house
# City not found. Skipping...
# Processing Record 48 of Set 6 | araguari
# Processing Record 49 of Set 6 | yar-sale
# Processing Record 50 of Set 6 | kandrian
# Processing Record 1 of Set 7 | gizo
# Processing Record 2 of Set 7 | peace river
# Processing Record 3 of Set 7 | faya
# Processing Record 4 of Set 7 | beringovskiy
# Processing Record 5 of Set 7 | port hardy
# Processing Record 6 of Set 7 | talara
# Processing Record 7 of Set 7 | camacha
# Processing Record 8 of Set 7 | washougal
# Processing Record 9 of Set 7 | baherden
# Processing Record 10 of Set 7 | puerto carreno
# Processing Record 11 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 12 of Set 7 | bafq
# Processing Record 13 of Set 7 | arlit
# Processing Record 14 of Set 7 | hasaki
# Processing Record 15 of Set 7 | mount gambier
# Processing Record 16 of Set 7 | akonolinga
# Processing Record 17 of Set 7 | areka
# Processing Record 18 of Set 7 | dingle
# Processing Record 19 of Set 7 | slave lake
# Processing Record 20 of Set 7 | solnechnyy
# Processing Record 21 of Set 7 | skagastrond
# City not found. Skipping...
# Processing Record 22 of Set 7 | haines junction
# Processing Record 23 of Set 7 | tsabong
# Processing Record 24 of Set 7 | bintulu
# Processing Record 25 of Set 7 | dwarka
# Processing Record 26 of Set 7 | congomah
# Processing Record 27 of Set 7 | makakilo city
# Processing Record 28 of Set 7 | cartagena del chaira
# Processing Record 29 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 7 | sobolevo
# Processing Record 31 of Set 7 | monroe
# Processing Record 32 of Set 7 | keetmanshoop
# Processing Record 33 of Set 7 | grand gaube
# Processing Record 34 of Set 7 | saint-pierre
# Processing Record 35 of Set 7 | ancud
# Processing Record 36 of Set 7 | linhares
# Processing Record 37 of Set 7 | anjiang
# Processing Record 38 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 7 | torres
# Processing Record 40 of Set 7 | doha
# Processing Record 41 of Set 7 | havre-saint-pierre
# Processing Record 42 of Set 7 | flin flon
# Processing Record 43 of Set 7 | labuhan
# Processing Record 44 of Set 7 | fukue
# Processing Record 45 of Set 7 | sao joao da barra
# Processing Record 46 of Set 7 | cabras
# Processing Record 47 of Set 7 | alta floresta
# Processing Record 48 of Set 7 | dakar
# Processing Record 49 of Set 7 | jacareacanga
# Processing Record 50 of Set 7 | drayton valley
# Processing Record 1 of Set 8 | zhicheng
# Processing Record 2 of Set 8 | harlingen
# Processing Record 3 of Set 8 | mildura
# Processing Record 4 of Set 8 | camacupa
# Processing Record 5 of Set 8 | shetpe
# Processing Record 6 of Set 8 | hukuntsi
# Processing Record 7 of Set 8 | pucallpa
# Processing Record 8 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 8 | sabha
# Processing Record 11 of Set 8 | am timan
# Processing Record 12 of Set 8 | priiskovyy
# Processing Record 13 of Set 8 | danbury
# Processing Record 14 of Set 8 | strezhevoy
# Processing Record 15 of Set 8 | kismayo
# Processing Record 16 of Set 8 | moron
# Processing Record 17 of Set 8 | zyryanovsk
# Processing Record 18 of Set 8 | fomboni
# Processing Record 19 of Set 8 | buchanan
# Processing Record 20 of Set 8 | lavrentiya
# Processing Record 21 of Set 8 | gimbi
# Processing Record 22 of Set 8 | fayaoue
# Processing Record 23 of Set 8 | uglich
# Processing Record 24 of Set 8 | nauta
# Processing Record 25 of Set 8 | cabedelo
# Processing Record 26 of Set 8 | shchigry
# Processing Record 27 of Set 8 | phan thiet
# Processing Record 28 of Set 8 | launceston
# Processing Record 29 of Set 8 | andenes
# Processing Record 30 of Set 8 | mayya
# Processing Record 31 of Set 8 | pisco
# Processing Record 32 of Set 8 | komsomolets
# Processing Record 33 of Set 8 | namatanai
# Processing Record 34 of Set 8 | la palma
# Processing Record 35 of Set 8 | riviere-au-renard
# Processing Record 36 of Set 8 | correntina
# Processing Record 37 of Set 8 | kabwe
# Processing Record 38 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 8 | staunton
# Processing Record 40 of Set 8 | bengkulu
# Processing Record 41 of Set 8 | turayf
# Processing Record 42 of Set 8 | bubaque
# Processing Record 43 of Set 8 | monrovia
# Processing Record 44 of Set 8 | aykhal
# Processing Record 45 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 46 of Set 8 | kirakira
# Processing Record 47 of Set 8 | mana
# Processing Record 48 of Set 8 | havelock
# Processing Record 49 of Set 8 | emerald
# Processing Record 50 of Set 8 | mecca
# Processing Record 1 of Set 9 | kutum
# Processing Record 2 of Set 9 | westerland
# Processing Record 3 of Set 9 | luganville
# Processing Record 4 of Set 9 | izberbash
# Processing Record 5 of Set 9 | baracoa
# Processing Record 6 of Set 9 | aguada
# Processing Record 7 of Set 9 | batticaloa
# Processing Record 8 of Set 9 | berlevag
# Processing Record 9 of Set 9 | beloha
# Processing Record 10 of Set 9 | wewak
# Processing Record 11 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 9 | puerto madryn
# Processing Record 13 of Set 9 | geraldton
# Processing Record 14 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 9 | ucluelet
# Processing Record 16 of Set 9 | kudahuvadhoo
# Processing Record 17 of Set 9 | hofn
# Processing Record 18 of Set 9 | molochnoye
# Processing Record 19 of Set 9 | ballina
# Processing Record 20 of Set 9 | morehead
# Processing Record 21 of Set 9 | songea
# Processing Record 22 of Set 9 | ardmore
# Processing Record 23 of Set 9 | hobyo
# Processing Record 24 of Set 9 | tombouctou
# Processing Record 25 of Set 9 | ngunguru
# Processing Record 26 of Set 9 | oak ridge
# Processing Record 27 of Set 9 | batemans bay
# Processing Record 28 of Set 9 | anito
# Processing Record 29 of Set 9 | morondava
# Processing Record 30 of Set 9 | poronaysk
# Processing Record 31 of Set 9 | kebemer
# City not found. Skipping...
# Processing Record 32 of Set 9 | nan
# Processing Record 33 of Set 9 | portland
# Processing Record 34 of Set 9 | felidhoo
# City not found. Skipping...
# Processing Record 35 of Set 9 | birao
# Processing Record 36 of Set 9 | reconquista
# Processing Record 37 of Set 9 | kingaroy
# Processing Record 38 of Set 9 | vao
# Processing Record 39 of Set 9 | olafsvik
# Processing Record 40 of Set 9 | salamiyah
# Processing Record 41 of Set 9 | sangar
# Processing Record 42 of Set 9 | yinchuan
# Processing Record 43 of Set 9 | diebougou
# Processing Record 44 of Set 9 | novoorsk
# Processing Record 45 of Set 9 | richards bay
# Processing Record 46 of Set 9 | krasnogvardeyets
# Processing Record 47 of Set 9 | gongzhuling
# Processing Record 48 of Set 9 | axixa do tocantins
# City not found. Skipping...
# Processing Record 49 of Set 9 | baturaja
# Processing Record 50 of Set 9 | nenjiang
# Processing Record 1 of Set 10 | atar
# Processing Record 2 of Set 10 | takoradi
# Processing Record 3 of Set 10 | piracanjuba
# Processing Record 4 of Set 10 | yulara
# Processing Record 5 of Set 10 | santiago del estero
# Processing Record 6 of Set 10 | abha
# Processing Record 7 of Set 10 | agua dulce
# Processing Record 8 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 9 of Set 10 | chabahar
# Processing Record 10 of Set 10 | latung
# Processing Record 11 of Set 10 | tyret pervaya
# Processing Record 12 of Set 10 | saskylakh
# Processing Record 13 of Set 10 | pajapan
# Processing Record 14 of Set 10 | rabo de peixe
# Processing Record 15 of Set 10 | cururupu
# Processing Record 16 of Set 10 | cocorit
# Processing Record 17 of Set 10 | longyearbyen
# Processing Record 18 of Set 10 | novoagansk
# Processing Record 19 of Set 10 | lumeje
# Processing Record 20 of Set 10 | mahibadhoo
# Processing Record 21 of Set 10 | ambanja
# Processing Record 22 of Set 10 | kingsport
# Processing Record 23 of Set 10 | grants
# Processing Record 24 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 10 | zambezi
# Processing Record 26 of Set 10 | kulhudhuffushi
# Processing Record 27 of Set 10 | golden
# Processing Record 28 of Set 10 | jalu
# Processing Record 29 of Set 10 | kaduy
# Processing Record 30 of Set 10 | hailar
# Processing Record 31 of Set 10 | jamsa
# Processing Record 32 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 33 of Set 10 | gwanda
# Processing Record 34 of Set 10 | jibuti
# Processing Record 35 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 36 of Set 10 | gurupi
# Processing Record 37 of Set 10 | placer
# Processing Record 38 of Set 10 | abbeville
# Processing Record 39 of Set 10 | xinqing
# Processing Record 40 of Set 10 | aklavik
# Processing Record 41 of Set 10 | leningradskiy
# Processing Record 42 of Set 10 | ahipara
# Processing Record 43 of Set 10 | kadaya
# Processing Record 44 of Set 10 | mehamn
# Processing Record 45 of Set 10 | winton
# Processing Record 46 of Set 10 | avinurme
# Processing Record 47 of Set 10 | bara
# Processing Record 48 of Set 10 | tual
# Processing Record 49 of Set 10 | seoul
# Processing Record 50 of Set 10 | sale
# Processing Record 1 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 2 of Set 11 | camabatela
# Processing Record 3 of Set 11 | namtsy
# Processing Record 4 of Set 11 | airai
# Processing Record 5 of Set 11 | taitung
# Processing Record 6 of Set 11 | mancora
# Processing Record 7 of Set 11 | necochea
# Processing Record 8 of Set 11 | huarmey
# Processing Record 9 of Set 11 | karratha
# Processing Record 10 of Set 11 | shache
# Processing Record 11 of Set 11 | san policarpo
# Processing Record 12 of Set 11 | vung tau
# Processing Record 13 of Set 11 | sinjai
# Processing Record 14 of Set 11 | porto nacional
# Processing Record 15 of Set 11 | haibowan
# City not found. Skipping...
# Processing Record 16 of Set 11 | krasnoselkup
# Processing Record 17 of Set 11 | ayios kirikos
# City not found. Skipping...
# Processing Record 18 of Set 11 | matamoros
# Processing Record 19 of Set 11 | geilo
# Processing Record 20 of Set 11 | skibbereen
# Processing Record 21 of Set 11 | teyateyaneng
# Processing Record 22 of Set 11 | angoche
# Processing Record 23 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 11 | groton
# Processing Record 25 of Set 11 | kibala
# Processing Record 26 of Set 11 | caceres
# Processing Record 27 of Set 11 | high level
# Processing Record 28 of Set 11 | duobao
# Processing Record 29 of Set 11 | los llanos de aridane
# Processing Record 30 of Set 11 | ellensburg
# Processing Record 31 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 32 of Set 11 | madimba
# Processing Record 33 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 34 of Set 11 | sulphur
# Processing Record 35 of Set 11 | komsomolskiy
# Processing Record 36 of Set 11 | carutapera
# Processing Record 37 of Set 11 | rocha
# Processing Record 38 of Set 11 | pandan
# Processing Record 39 of Set 11 | capaci
# Processing Record 40 of Set 11 | tselinnoye
# Processing Record 41 of Set 11 | jambi
# Processing Record 42 of Set 11 | miles city
# Processing Record 43 of Set 11 | vila do maio
# Processing Record 44 of Set 11 | cayenne
# Processing Record 45 of Set 11 | ishigaki
# Processing Record 46 of Set 11 | batagay-alyta
# Processing Record 47 of Set 11 | banda aceh
# Processing Record 48 of Set 11 | aviles
# Processing Record 49 of Set 11 | tomatlan
# Processing Record 50 of Set 11 | las palmas
# Processing Record 1 of Set 12 | qurayyat
# Processing Record 2 of Set 12 | hopelchen
# Processing Record 3 of Set 12 | le port
# Processing Record 4 of Set 12 | cidreira
# Processing Record 5 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 12 | malindi
# Processing Record 7 of Set 12 | willowmore
# Processing Record 8 of Set 12 | ariquemes
# Processing Record 9 of Set 12 | tokur
# Processing Record 10 of Set 12 | cacule
# Processing Record 11 of Set 12 | rio claro
# Processing Record 12 of Set 12 | yatou
# Processing Record 13 of Set 12 | victor harbor
# Processing Record 14 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 12 | praya
# Processing Record 16 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 12 | leshukonskoye
# Processing Record 18 of Set 12 | tangshan
# Processing Record 19 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 20 of Set 12 | codrington
# Processing Record 21 of Set 12 | urrao
# Processing Record 22 of Set 12 | chicama
# Processing Record 23 of Set 12 | port hedland
# Processing Record 24 of Set 12 | caucaia
# Processing Record 25 of Set 12 | lincoln
# Processing Record 26 of Set 12 | xichang
# Processing Record 27 of Set 12 | linxia
# Processing Record 28 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 30 of Set 12 | southbridge
# Processing Record 31 of Set 12 | korablino
# Processing Record 32 of Set 12 | babstovo
# Processing Record 33 of Set 12 | chapais
# Processing Record 34 of Set 12 | tlahualilo
# City not found. Skipping...
# Processing Record 35 of Set 12 | gudalur
# Processing Record 36 of Set 12 | adrar
# Processing Record 37 of Set 12 | kifri
# Processing Record 38 of Set 12 | maniitsoq
# Processing Record 39 of Set 12 | jojoima
# Processing Record 40 of Set 12 | sur
# Processing Record 41 of Set 12 | longwy
# Processing Record 42 of Set 12 | robertsport
# Processing Record 43 of Set 12 | bac lieu
# Processing Record 44 of Set 12 | marzuq
# Processing Record 45 of Set 12 | bonfim
# Processing Record 46 of Set 12 | saint combs
# City not found. Skipping...
# Processing Record 47 of Set 12 | kologriv
# Processing Record 48 of Set 12 | saint augustine
# Processing Record 49 of Set 12 | dalbandin
# Processing Record 50 of Set 12 | alugan
# Processing Record 1 of Set 13 | baykit
# Processing Record 2 of Set 13 | la ronge
# Processing Record 3 of Set 13 | kruisfontein
# Processing Record 4 of Set 13 | mayo
# Processing Record 5 of Set 13 | itarema
# Processing Record 6 of Set 13 | ubrique
# Processing Record 7 of Set 13 | klaksvik
# Processing Record 8 of Set 13 | mokolo
# Processing Record 9 of Set 13 | mafinga
# Processing Record 10 of Set 13 | prado
# Processing Record 11 of Set 13 | natal
# Processing Record 12 of Set 13 | miyako
# Processing Record 13 of Set 13 | jerome
# Processing Record 14 of Set 13 | peniche
# Processing Record 15 of Set 13 | brora
# Processing Record 16 of Set 13 | lasa
# Processing Record 17 of Set 13 | varkkallai
# Processing Record 18 of Set 13 | pontianak
# Processing Record 19 of Set 13 | wynyard
# Processing Record 20 of Set 13 | armizonskoye
# Processing Record 21 of Set 13 | roseburg
# Processing Record 22 of Set 13 | mandalgovi
# Processing Record 23 of Set 13 | stornoway
# Processing Record 24 of Set 13 | bajil
# Processing Record 25 of Set 13 | nivala
# Processing Record 26 of Set 13 | port lincoln
# Processing Record 27 of Set 13 | aginskoye
# Processing Record 28 of Set 13 | sampang
# Processing Record 29 of Set 13 | bolobo
# Processing Record 30 of Set 13 | bassila
# Processing Record 31 of Set 13 | kysyl-syr
# Processing Record 32 of Set 13 | zyryanka
# Processing Record 33 of Set 13 | merauke
# Processing Record 34 of Set 13 | tankhoy
# Processing Record 35 of Set 13 | front royal
# Processing Record 36 of Set 13 | nampula
# Processing Record 37 of Set 13 | shakawe
# Processing Record 38 of Set 13 | huilong
# Processing Record 39 of Set 13 | raudeberg
# Processing Record 40 of Set 13 | usogorsk
# Processing Record 41 of Set 13 | plettenberg bay
# Processing Record 42 of Set 13 | ust-nera
# Processing Record 43 of Set 13 | wanaka
# Processing Record 44 of Set 13 | wilmington
# Processing Record 45 of Set 13 | chokwe
# Processing Record 46 of Set 13 | skiros
# City not found. Skipping...
# Processing Record 47 of Set 13 | hirara
# Processing Record 48 of Set 13 | pochutla
# Processing Record 49 of Set 13 | puerto narino
# Processing Record 50 of Set 13 | pangai
# Processing Record 1 of Set 14 | hualmay
# Processing Record 2 of Set 14 | garissa
# Processing Record 3 of Set 14 | hearst
# Processing Record 4 of Set 14 | nidamangalam
# Processing Record 5 of Set 14 | dunedin
# Processing Record 6 of Set 14 | puerto escondido
# Processing Record 7 of Set 14 | avera
# Processing Record 8 of Set 14 | bokoro
# Processing Record 9 of Set 14 | hvolsvollur
# Processing Record 10 of Set 14 | cap-aux-meules
# Processing Record 11 of Set 14 | itanagar
# Processing Record 12 of Set 14 | black diamond
# Processing Record 13 of Set 14 | kizel
# Processing Record 14 of Set 14 | anadyr
# Processing Record 15 of Set 14 | yuanping
# Processing Record 16 of Set 14 | sabang
# Processing Record 17 of Set 14 | opole lubelskie
# Processing Record 18 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 14 | krasnaya poyma
# Processing Record 20 of Set 14 | seymchan
# Processing Record 21 of Set 14 | kurumkan
# Processing Record 22 of Set 14 | tyukalinsk
# Processing Record 23 of Set 14 | tazovskiy
# Processing Record 24 of Set 14 | campo maior
# Processing Record 25 of Set 14 | chumikan
# Processing Record 26 of Set 14 | maamba
# Processing Record 27 of Set 14 | gamba
# Processing Record 28 of Set 14 | saryshagan
# City not found. Skipping...
# Processing Record 29 of Set 14 | vestmanna
# Processing Record 30 of Set 14 | amapa
# Processing Record 31 of Set 14 | reze
# Processing Record 32 of Set 14 | lere
# Processing Record 33 of Set 14 | champerico
# Processing Record 34 of Set 14 | antofagasta
# Processing Record 35 of Set 14 | sechura
# Processing Record 36 of Set 14 | baruun-urt
# Processing Record 37 of Set 14 | george town
# Processing Record 38 of Set 14 | otukpo
# Processing Record 39 of Set 14 | jining
# Processing Record 40 of Set 14 | rassvet
# Processing Record 41 of Set 14 | puri
# Processing Record 42 of Set 14 | eydhafushi
# Processing Record 43 of Set 14 | suntar
# Processing Record 44 of Set 14 | egvekinot
# Processing Record 45 of Set 14 | xai-xai
# Processing Record 46 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 47 of Set 14 | cochabamba
# Processing Record 48 of Set 14 | iquitos
# Processing Record 49 of Set 14 | lloydminster
# Processing Record 50 of Set 14 | raxaul
# Processing Record 1 of Set 15 | filingue
# Processing Record 2 of Set 15 | kikwit
# Processing Record 3 of Set 15 | poum
# Processing Record 4 of Set 15 | maumere
# Processing Record 5 of Set 15 | acapulco
# Processing Record 6 of Set 15 | uchaly
# Processing Record 7 of Set 15 | puerto baquerizo moreno
# Processing Record 8 of Set 15 | kozluk
# Processing Record 9 of Set 15 | margate
# Processing Record 10 of Set 15 | sistranda
# Processing Record 11 of Set 15 | kouvola
# Processing Record 12 of Set 15 | zamboanguita
# Processing Record 13 of Set 15 | kahului
# Processing Record 14 of Set 15 | fairbanks
# Processing Record 15 of Set 15 | maputo
# Processing Record 16 of Set 15 | kigoma
# Processing Record 17 of Set 15 | kitui
# Processing Record 18 of Set 15 | kasongo
# Processing Record 19 of Set 15 | honningsvag
# Processing Record 20 of Set 15 | maloshuyka
# City not found. Skipping...
# Processing Record 21 of Set 15 | ilam
# Processing Record 22 of Set 15 | xining
# Processing Record 23 of Set 15 | san ramon
# Processing Record 24 of Set 15 | atbasar
# Processing Record 25 of Set 15 | gat
# Processing Record 26 of Set 15 | palmital
# Processing Record 27 of Set 15 | chapada dos guimaraes
# Processing Record 28 of Set 15 | majene
# Processing Record 29 of Set 15 | puerto cabezas
# Processing Record 30 of Set 15 | beyneu
# Processing Record 31 of Set 15 | kaeo
# Processing Record 32 of Set 15 | karamay
# City not found. Skipping...
# Processing Record 33 of Set 15 | la primavera
# Processing Record 34 of Set 15 | marv dasht
# City not found. Skipping...
# Processing Record 35 of Set 15 | husavik
# Processing Record 36 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 37 of Set 15 | mitchell
# Processing Record 38 of Set 15 | praxedis guerrero
# Processing Record 39 of Set 15 | sorland
# Processing Record 40 of Set 15 | zyryanovskiy
# City not found. Skipping...
# Processing Record 41 of Set 15 | riyadh
# Processing Record 42 of Set 15 | vila franca do campo
# Processing Record 43 of Set 15 | mikhaylovka
# Processing Record 44 of Set 15 | tunduru
# City not found. Skipping...
# Processing Record 45 of Set 15 | boddam
# Processing Record 46 of Set 15 | zavallya
# Processing Record 47 of Set 15 | sisimiut
# Processing Record 48 of Set 15 | russell
# Processing Record 49 of Set 15 | caravelas
# Processing Record 50 of Set 15 | hervey bay
# Processing Record 1 of Set 16 | porto franco
# Processing Record 2 of Set 16 | carballo
# Processing Record 3 of Set 16 | maneromango
# Processing Record 4 of Set 16 | vidalia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#       City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   Albany  42.6001  -73.9662     39.00        65          96        4.00
# 1   Calvia  39.5657    2.5062     59.00        67           0       10.36
# 2   Son La  21.3167  103.9000     47.41        79          97        3.11
# 3  Rikitea -23.1203 -134.9692     78.03        77           0       15.26
# 4     Lebu -37.6167  -73.6500     61.05        72           0       20.54
#
#   Country                 Date Current Conditions
# 0      US  2021-01-17 16:29:12    overcast clouds
# 1      ES  2021-01-17 16:29:12          clear sky
# 2      VN  2021-01-17 16:29:12    overcast clouds
# 3      PF  2021-01-17 16:29:13         light rain
# 4      CL  2021-01-17 16:29:13          clear sky

# %%
column_order= ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Conditions', 'Date']

city_data_df= city_data_df[column_order]
city_data_df.head()
# Out:
#       City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Albany      US  42.6001  -73.9662     39.00        65          96
# 1   Calvia      ES  39.5657    2.5062     59.00        67           0
# 2   Son La      VN  21.3167  103.9000     47.41        79          97
# 3  Rikitea      PF -23.1203 -134.9692     78.03        77           0
# 4     Lebu      CL -37.6167  -73.6500     61.05        72           0
#
#    Wind Speed Current Conditions                 Date
# 0        4.00    overcast clouds  2021-01-17 16:29:12
# 1       10.36          clear sky  2021-01-17 16:29:12
# 2        3.11    overcast clouds  2021-01-17 16:29:12
# 3       15.26         light rain  2021-01-17 16:29:13
# 4       20.54          clear sky  2021-01-17 16:29:13

# %%
# Create a CSV
output_file= "weather_database/WeatherPy_database.csv"

city_data_df.to_csv(output_file, index_label="City_ID")
